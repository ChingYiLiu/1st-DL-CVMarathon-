# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# 沒有反爬的狀態
res = requests.get('https://github.com/new',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Sign in to GitHub · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
# GitHub no longer supports this web browser.
#
#           Learn more about the browsers we support.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sign in to GitHub
#
#
#
#
#
#
#
#
# ...

# %%
res = requests.get('https://github.com/new')
print(res.cookies)
# Out:
# <RequestsCookieJar[<Cookie _device_id=9cbad8503c1fcc48917be7507ffb9758 for github.com/>, <Cookie _gh_sess=uwi6RFBfdV36ApAJjt89Hq8t80p3q7nFwHf91%2F9RDu23Q56FMVe3pkqfA%2FWlqEqYOVnW0ajmHA2NaByDRWc4OfbA4PaSeYgXPWAVBF8fD44Dfs2a7uC%2BgJc3H39KY78cGJDW9CCKBYN4WghO0Z%2Byv9nJzcNP2N4eZd80ja1aS%2FcIbDWpfgKL3Lu9f3Pw9ILiro59QVpX77DxeSauanz55mqmceFtZUtLMIRjptB1sUcVIUdgk3z5hLsM%2FHGpJ%2FESqgFKvEvPN33Ie9TMuH%2B43g%3D%3D--kkpIdXpP1nm3b9Ei--Hg5j%2F1FC2Sa4lSX9gm%2F%2BoA%3D%3D for github.com/>]>

# %%
# 嘗試反爬

# %%
rs = requests.session()
payload={
    'return_to':'https://github.com/new',
    'authenticity_token':'GvqIRHSGvUO0j1j549IWXGT+1S2QEJ//M46TX9JB/HhNKi3ZnPE92HV9L77PiKZJW8n1ZJ9zkVSuvTOJXbUvyQ==',
    'otp': '937239'
}
header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
}

# %%
res = rs.post('https://github.com/login',verify = False, data = payload)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
res = rs.get('https://github.com/new',verify = False)
soup = BeautifulSoup(res.text)
print(soup.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Sign in to GitHub · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
# GitHub no longer supports this web browser.
#
#           Learn more about the browsers we support.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sign in to GitHub
#
#
#
#
#
#
#
#
# ...
